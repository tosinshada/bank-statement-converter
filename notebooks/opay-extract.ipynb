# %%
from datetime import datetime

import camelot
import pandas as pd

# %%
# Configuration
PDF_FILE_PATH = '../docs/statement-2.pdf'
DATE_FORMAT = "%m/%d/%Y"

# Column Headers from the Document
COLUMN_NAMES = [
    "Trans. Time",
    "Value Date",
    "Description",
    "Debit/Credit(N)",
    "Balance(N)",
    "Channel",
    "Transaction Reference"
]

def is_valid_date(date_string: str) -> bool:
    """Check if a string matches 'YYYY Mon DD HH:MM:SS'."""
    try:
        datetime.strptime(date_string, "%Y %b %d %H:%M:%S")
        return True
    except ValueError:
        return False

def build_transactions_with_validation(raw_df: pd.DataFrame) -> pd.DataFrame:
    """
    The `build_transactions_with_validation` function processes a raw DataFrame of transaction data
    and constructs a cleaned DataFrame of transactions by identifying valid transaction boundaries
    based on date validation. The logic is as follows:

    1. **Initialize Variables**:
        - `transactions`: A list to store completed transactions.
        - `transaction_in_progress`: A dictionary to hold the current transaction being built.
        - `valid_transaction`: A flag to indicate if the current transaction is valid.

    2. **Iterate Through Rows**:
        - For each row, check if the first column contains a valid timestamp using the `is_valid_date` function.
        - If a valid timestamp is found:
            - Append the current `transaction_in_progress` to the `transactions` list (if it exists).
            - Start a new transaction with the current row.
            - Set `valid_transaction` to `True`.
        - If no valid timestamp is found:
            - If no transaction is in progress, initialize `transaction_in_progress` with the current row.
            - Otherwise, concatenate the current row's data into the existing `transaction_in_progress`.
            - If the concatenated data forms a valid timestamp, set `valid_transaction` to `True`.

    3. **Handle Remaining Transaction**:
        - After iterating through all rows, append the last `transaction_in_progress` to the `transactions` list.

    4. **Return Result**:
        - Convert the `transactions` list into a DataFrame and return it.

    Reasoning:
    This function is due to the fact that when opay transactions spills to the next line at the end of the page, it doesn't
    start recording most of the columns on the first line causing an issue when using the `concatenate_rows_until_balance` function
    as done for other banks. Instead, we will check for valid timestamps to determine the partitioning of transactions.
    """
    transactions = []
    transaction_in_progress = {}
    valid_transaction = False

    display(raw_df.head(50))

    for _, row in raw_df.iterrows():
        timestamp_candidate = str(row.iloc[0]).strip()
        if is_valid_date(timestamp_candidate):
            if transaction_in_progress:
                transactions.append(transaction_in_progress)
            transaction_in_progress = row.to_dict()
            valid_transaction = True
        elif not transaction_in_progress:
            transaction_in_progress = row.to_dict()
        else:
            if valid_transaction:
                merged_date = transaction_in_progress[raw_df.columns[0]] + timestamp_candidate
                if not is_valid_date(merged_date):
                    transactions.append(transaction_in_progress)
                    transaction_in_progress = row.to_dict()
                    valid_transaction = False
                    continue
            for col in raw_df.columns:
                existing_val = transaction_in_progress.get(col, "")
                transaction_in_progress[col] = f"{existing_val}{row[col]}".strip()

            if is_valid_date(transaction_in_progress[raw_df.columns[0]]):
                valid_transaction = True

    if transaction_in_progress:
        transactions.append(transaction_in_progress)

    return pd.DataFrame(transactions)

def extract_and_clean_transactions(pdf_path: str) -> pd.DataFrame:
    """Extract, build, and clean transaction data from a PDF."""
    print("Starting extraction...")
    tables = camelot.read_pdf(pdf_path, pages='all', flavor='stream', row_tol=10)

    num_columns = len(COLUMN_NAMES)
    raw_df = pd.concat([table.df for table
                                 in tables
                                 if table.df.shape[1] == num_columns], ignore_index=True)
    raw_df.dropna(axis=1, how='all', inplace=True)

    raw_df.columns = COLUMN_NAMES[:num_columns]

    print("Building transactions with validation logic...")
    transactions_df = build_transactions_with_validation(raw_df)

    print("Performing final data cleaning...")
    cleaned_df = transactions_df.copy()

    # Clean up newline characters and leading/trailing spaces
    for col in cleaned_df.columns:
        if cleaned_df[col].dtype == 'object':
            cleaned_df.loc[:, col] = (
                cleaned_df[col]
                .str.replace('\n', ' ', regex=False)
                .str.strip()
            )

    def clean_numeric_col(series: pd.Series) -> pd.Series:
        # Remove commas, letters, and any non-numeric characters except for '.' and '-'
        cleaned_series = series.astype(str).str.replace(',', '', regex=False)
        cleaned_series = cleaned_series.str.replace(r'[^\d.-]', '', regex=True)
        return pd.to_numeric(cleaned_series, errors='coerce')

    cleaned_df.loc[:, 'Debit/Credit(N)'] = clean_numeric_col(cleaned_df['Debit/Credit(N)'])
    cleaned_df.loc[:, 'Balance(N)'] = clean_numeric_col(cleaned_df['Balance(N)'])

    cleaned_df.loc[:, 'Trans. Time'] = pd.to_datetime(
        cleaned_df['Trans. Time'],
        format="%Y %b %d %H:%M:%S",
        errors='coerce'
    )
    cleaned_df.loc[:, 'Value Date'] = pd.to_datetime(
        cleaned_df['Value Date'],
        format="%d %b %Y",
        errors='coerce'
    )

    cleaned_df = cleaned_df[cleaned_df['Trans. Time'].notna()]
    cleaned_df.reset_index(drop=True, inplace=True)

    print("Extraction and cleaning complete.")
    return cleaned_df

# %%
if __name__ == '__main__':
    # --- Execute the script ---
    final_transactions_df = extract_and_clean_transactions(PDF_FILE_PATH)

    # --- Display Results ---
    print("\n--- Extracted Transactions ---")
    print(f"Total transactions extracted: {len(final_transactions_df)}")

    # Display the first 50 and last 50 transactions
    print("\nFirst 50 Transactions:")
    display(final_transactions_df.head(50))

    print("\nLast 50 Transactions:")
    display(final_transactions_df.tail(50))

    # --- Optional: Save to CSV ---
    try:
        output_csv_path = f'../output/opay_extracted_transactions{datetime.now().strftime('%d%m%Y%H%M%S')}.csv'
        final_transactions_df.to_csv(output_csv_path, date_format=DATE_FORMAT, index=False)
        print(f"\nSuccessfully saved cleaned data to '{output_csv_path}'")
    except Exception as e:
        print(f"\nCould not save to CSV: {e}")
# Out:
# Starting extraction...
# Building transactions with validation logic...
# /Users/user/Repos/Personal/bank-statement-converter/.venv/lib/python3.12/site-packages/camelot/parsers/base.py:218: UserWarning: No tables found on page-20
#   if self._document_has_no_text():
#              Trans. Time   Value Date  \
# 0            Trans. Time   Value Date
# 1   2025 Jan 02 12:30:18  02 Jan 2025
# 2     2025 Jan 02 19:34:  02 Jan 2025
# 3                     57
# 4     2025 Jan 04 07:55:  04 Jan 2025
# 5                     18
# 34
# 35                                 OPay Card Payment        -9,997.50
# 36                                 OPay Card Payment        -1,400.00
# 37         Transfer from IHEANYICHUKWU NWANKWO OBASI       +40,000.00
# 38
# 39                    Electronic Money Transfer Levy           -50.00
# 40
# 41                                 OPay Card Payment        -8,800.00
# 42                                           Airtime        -5,000.00
# 43
# 44                                 OPay Card Payment       -26,166.33
# 45                                 OPay Card Payment        -7,800.00
# 46                  Transfer to AUGUSTINE AUDU ATAYI       -15,000.00
# 47                  Transfer to AKPELA SIMON IORGEMA        -2,000.00
# 48
# 49                                 OPay Card Payment       -10,330.75
#
#       Balance(N)    Channel           Transaction Reference
# 0     Balance(₦)    Channel           Transaction Reference
# 1     242,859.33  E-Channel        250102330100645707036016
# 2     234,859.33        POS        250102330100651099721981
# 3
# 4     234,799.33  E-Channel        250104140200667984787233
# 5
# 6     230,284.33  E-Channel        250105330100682686169895
# 7
# 8     196,964.41        POS        250105330100688931690018
# 9     193,164.41  E-Channel        250106010100692793802279
# 10
# 11    185,736.16  E-Channel        250106330100697012151221
# 12
# 13  1,185,736.16  E-Channel  000012250106182106998609553918
# 14
# 15  1,185,686.16  E-Channel        250106140200700331738613
# 16  1,127,634.16        POS        250106330100702983351015
# 17
# 18  1,111,804.16  E-Channel        250107330100709873796040
# 19  1,031,404.16        POS        250107330100716482596502
# 20
# 21  1,058,204.16  E-Channel  000001250107213026179216857718
# 22
# 23  1,058,154.16  E-Channel        250107140200716451188456
# 24
# 25  1,088,154.16  E-Channel       09FG2501072132330766HY41H
# 26
# 27  1,088,104.16  E-Channel        250107140200716402552945
# 28  1,086,104.16  E-Channel        250107010100717081133236
# 29
# 30  1,078,176.66  E-Channel        250108330100722008012867
# 31  1,043,176.66  E-Channel        250108100100723987591398
# 32
# 33  1,038,974.16  E-Channel  100004250109145548125169192565
# 34
# 35  1,028,976.66  E-Channel        250110330100749100450225
# 36  1,027,576.66        POS        250110330100749502209644
# 37  1,067,576.66  E-Channel  000014250110135938284613019434
# 38
# 39  1,067,526.66  E-Channel        250110140200750287818170
# 40
# 41  1,058,726.66        POS        250111330100768190280519
# 42  1,053,726.66       USSD        250112100100774240413073
# 43
# 44  1,027,560.33  E-Channel        250112330100776464380590
# 45  1,019,760.33        POS        250112330100779923037930
# 46  1,004,760.33  E-Channel        250112010100780206934569
# 47  1,002,760.33  E-Channel        250113010100786485145437
# 48
# 49    992,429.58  E-Channel        250113330100788583177960
# Total completed transactions: 452
#              Trans. Time   Value Date  \
# 0            Trans. Time   Value Date
# 1   2025 Jan 02 12:30:18  02 Jan 2025
# 2   2025 Jan 02 19:34:57  02 Jan 2025
# 3   2025 Jan 04 07:55:18  04 Jan 2025
# 4   2025 Jan 05 10:28:01  05 Jan 2025
# 5   2025 Jan 05 19:01:13  05 Jan 2025
# 6   2025 Jan 06 07:51:39  06 Jan 2025
# 7   2025 Jan 06 13:03:13  06 Jan 2025
# 12                                  OPay Card Payment       -80,400.00
# 13            Transfer from OLEWUENYI FAVOUR CHIKAMSO       +26,800.00
# 14                     Electronic Money Transfer Levy           -50.00
# 15          Transfer from LANRE-OLOGUN+OREOLUWA+ESOSA       +30,000.00
# 16                     Electronic Money Transfer Levy           -50.00
# 17                   Transfer to WUESE EPHRAIM IORHEN        -2,000.00
# 18                                  OPay Card Payment        -7,927.50
# 19                                            Airtime       -35,000.00
# 20   Transfer to Flutterwave/Isi Signature-Midddleman        -4,202.50
# 21                                  OPay Card Payment        -9,997.50
# 22                                  OPay Card Payment        -1,400.00
# 23          Transfer from IHEANYICHUKWU NWANKWO OBASI       +40,000.00
# 24                     Electronic Money Transfer Levy           -50.00
# 25                                  OPay Card Payment        -8,800.00
# 26                                            Airtime        -5,000.00
# 27                                  OPay Card Payment       -26,166.33
# 28                                  OPay Card Payment        -7,800.00
# 29                   Transfer to AUGUSTINE AUDU ATAYI       -15,000.00
# 30                   Transfer to AKPELA SIMON IORGEMA        -2,000.00
# 31                                  OPay Card Payment       -10,330.75
# 32                                  OPay Card Payment        -9,589.00
# 33                                  OPay Card Payment        -3,465.00
# 34                                  OPay Card Payment       -26,400.00
# 35               Transfer to MELODY CHINAGO SLYVESTER       -10,000.00
# 36                                  OPay Card Payment        -7,697.00
# 37                                  OPay Card Payment        -5,460.00
# 38                                  OPay Card Payment       -21,500.00
# 39                                  OPay Card Payment        -7,400.00
# 40                                  OPay Card Payment        -5,460.00
# 41  Transfer to Lemonade Technology Limited - PATR...      -400,000.00
# 42                                  OPay Card Payment       -42,500.00
# 43                                  OPay Card Payment        -9,300.00
# 44                                  OPay Card Payment       -12,427.00
# 45                                  OPay Card Payment       -11,954.00
# 46                                  OPay Card Payment       -78,000.00
# 47                                  OPay Card Payment       -35,700.00
# 48  Transfer to Lemonade Technology Limited - PATR...       -70,000.00
# 49                                  OPay Card Payment       -11,072.50
#
#       Balance(N)    Channel           Transaction Reference
# 0     Balance(₦)    Channel           Transaction Reference
# 1     242,859.33  E-Channel        250102330100645707036016
# 2     234,859.33        POS        250102330100651099721981
# 3     234,799.33  E-Channel        250104140200667984787233
# 4     230,284.33  E-Channel        250105330100682686169895
# 5     196,964.41        POS        250105330100688931690018
# 6     193,164.41  E-Channel        250106010100692793802279
# 7     185,736.16  E-Channel        250106330100697012151221
# 8   1,185,736.16  E-Channel  000012250106182106998609553918
# 9   1,185,686.16  E-Channel        250106140200700331738613
# 10  1,127,634.16        POS        250106330100702983351015
# 11  1,111,804.16  E-Channel        250107330100709873796040
# 12  1,031,404.16        POS        250107330100716482596502
# 13  1,058,204.16  E-Channel  000001250107213026179216857718
# 14  1,058,154.16  E-Channel        250107140200716451188456
# 15  1,088,154.16  E-Channel       09FG2501072132330766HY41H
# 16  1,088,104.16  E-Channel        250107140200716402552945
# 17  1,086,104.16  E-Channel        250107010100717081133236
# 22          Transfer from IHEANYICHUKWU NWANKWO OBASI         40000.0
# 23                     Electronic Money Transfer Levy           -50.0
# 24                                  OPay Card Payment         -8800.0
# 25                                            Airtime         -5000.0
# 26                                  OPay Card Payment       -26166.33
# 27                                  OPay Card Payment         -7800.0
# 28                   Transfer to AUGUSTINE AUDU ATAYI        -15000.0
# 29                   Transfer to AKPELA SIMON IORGEMA         -2000.0
# 30                                  OPay Card Payment       -10330.75
# 31                                  OPay Card Payment         -9589.0
# 32                                  OPay Card Payment         -3465.0
# 33                                  OPay Card Payment        -26400.0
# 34               Transfer to MELODY CHINAGO SLYVESTER        -10000.0
# 35                                  OPay Card Payment         -7697.0
# 36                                  OPay Card Payment         -5460.0
# 37                                  OPay Card Payment        -21500.0
# 38                                  OPay Card Payment         -7400.0
# 39                                  OPay Card Payment         -5460.0
# 40  Transfer to Lemonade Technology Limited - PATR...       -400000.0
# 41                                  OPay Card Payment        -42500.0
# 42                                  OPay Card Payment         -9300.0
# 43                                  OPay Card Payment        -12427.0
# 44                                  OPay Card Payment        -11954.0
# 45                                  OPay Card Payment        -78000.0
# 46                                  OPay Card Payment        -35700.0
# 47  Transfer to Lemonade Technology Limited - PATR...        -70000.0
# 48                                  OPay Card Payment        -11072.5
# 49                                  OPay Card Payment         -318.25
#
#     Balance(N)    Channel           Transaction Reference
# 0    242859.33  E-Channel        250102330100645707036016
# 1    234859.33        POS        250102330100651099721981
# 2    234799.33  E-Channel        250104140200667984787233
# 3    230284.33  E-Channel        250105330100682686169895
# 4    196964.41        POS        250105330100688931690018
# 5    193164.41  E-Channel        250106010100692793802279
# 6    185736.16  E-Channel        250106330100697012151221
# 7   1185736.16  E-Channel  000012250106182106998609553918
# 8   1185686.16  E-Channel        250106140200700331738613
# 9   1127634.16        POS        250106330100702983351015
# 10  1111804.16  E-Channel        250107330100709873796040
# 11  1031404.16        POS        250107330100716482596502
# 12  1058204.16  E-Channel  000001250107213026179216857718
# 13  1058154.16  E-Channel        250107140200716451188456
# 14  1088154.16  E-Channel       09FG2501072132330766HY41H
# 15  1088104.16  E-Channel        250107140200716402552945
# 16  1086104.16  E-Channel        250107010100717081133236
# 17  1078176.66  E-Channel        250108330100722008012867
# 18  1043176.66  E-Channel        250108100100723987591398
# 19  1038974.16  E-Channel  100004250109145548125169192565
# 20  1028976.66  E-Channel        250110330100749100450225
# 21  1027576.66        POS        250110330100749502209644
# 22  1067576.66  E-Channel  000014250110135938284613019434
# 23  1067526.66  E-Channel        250110140200750287818170
# 24  1058726.66        POS        250111330100768190280519
# 25  1053726.66       USSD        250112100100774240413073
# 26  1027560.33  E-Channel        250112330100776464380590
# 27  1019760.33        POS        250112330100779923037930
# 28  1004760.33  E-Channel        250112010100780206934569
# 29  1002760.33  E-Channel        250113010100786485145437
# 30   992429.58  E-Channel        250113330100788583177960
# 31   982840.58  E-Channel        250114330100802341018290
# 32   979375.58  E-Channel        250114330100802615083796
# 433                         OPay Card Payment         -5400.0  1016906.78
# 434          Transfer to ZAINAB OMOTAYO JIMOH         -1900.0  1015006.78
# 435                          SMS Subscription           -12.0  1014994.78
# 436     Transfer to OLEWUENYI FAVOUR CHIKAMSO       -195000.0   819994.78
# 437                         OPay Card Payment         -8800.0   811194.78
# 438        Transfer to GLORY DANIELLA OBIKORU         -6000.0   805194.78
# 439                         OPay Card Payment        -21521.5   783673.28
# 440                         OPay Card Payment         -9675.0   773998.28
# 441                         OPay Card Payment         -1350.0   772648.28
# 442                         OPay Card Payment       -23849.82   748798.46
# 443                         OPay Card Payment        -27037.0   721761.46
# 444                                   Airtime         -2000.0   719761.46
# 445                         OPay Card Payment        -15336.0   704425.46
# 446                         OPay Card Payment         -3834.0   700591.46
# 447                         OPay Card Payment         -3834.0   696757.46
# 448                         OPay Card Payment         -3834.0   692923.46
# 449          Transfer to KUNLE JOSHUA TOYINBO        -70000.0   622923.46
# 450                         OPay Card Payment         -8922.5   614000.96
#
#        Channel           Transaction Reference
# 401        POS        250518330100775950787467
# 402        POS        250518330100778271647455
# 403  E-Channel        250519100100783879761034
# 404  E-Channel  100004250519102353133029874198
# 405  E-Channel  000013250520081847000169406232
# 406  E-Channel        250520140200799042664346
# 407        POS        250520330100803305694300
# 408        POS        250520330100802921175193
# 409  E-Channel        250520330100810606214331
# 410        POS        250522330100843071257712
# 411        POS        250522330100843307852365
# 412  E-Channel  100004250523105531133288507410
# 413        POS        250523330100861131008922
# 414        POS        250524330100872002106598
# 415  E-Channel  100004250524195851133394359519
# 416  E-Channel        250525120100894876464890
# 417        POS        250525330100895035348217
# 418  E-Channel  100004250526074612133463818400
# 419        POS        250526330100912072705674
# 420        POS        250527330100931043526219
# 421  E-Channel        250527010100931110744485
# 422  E-Channel  100004250527191904133577876206
# 423  E-Channel  100004250528102842133606220431
# 424  E-Channel        250528010100947997310944
# 425        POS        250528330100947968540410
# 426        POS        250528330100948357173078
# 427  E-Channel  100004250530092752133734249216
# 428        POS        250530330100983456904404
# 429  E-Channel  100004250602092634133941240208
# 430  E-Channel       09FG2506021805199271RX0I5
# 431  E-Channel        250602140200039562386942
# 432  E-Channel        250603010100058487311923
# 433        POS        250603330100058781115941
# 434  E-Channel  100004250604092753134082414839
# 435  E-Channel        250604140200070811437539
# 436  E-Channel  100004250604151727134113063825
# 437        POS        250604330100078776761549
# 438  E-Channel        250604010100078697371033
# 439  E-Channel        250604330100081367227368
# 440  E-Channel        250605330100098082566338
# 441        POS        250606330100109534627492
# 442        POS        250606330100109457455798
# 443        POS        250606330100109654355271
# 444  E-Channel        250606100100110568670283
# 445  E-Channel        250606330100112344428507
# 446  E-Channel        250606330100113779646878
# 447  E-Channel        250606330100113835103247
# 448  E-Channel        250606330100113839458665
# 449  E-Channel        250606010100118005401062
# 450  E-Channel        250606330100118063340490
# Successfully saved cleaned data to '../output/opay_extracted_transactions15062025172417.csv'
